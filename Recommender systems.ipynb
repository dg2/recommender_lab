# %% [markdown]
# # Description
# In this lab session we will build a simple recommender for movies. During the process we will have the opportunity to practice data manipulation, sparse linear algebra and the Python data analysis ecosystem.
#
# We will be using the following libraries
#
# * **pandas**: The de-facto data manipulation library for Python. Based con the concept of a `DataFrame` (similar to R's). Provides a lot of functionality for importing / exporting data, filtering, transformations, \ldots
# * **numpy**: Vector and matrix operations. Wraps highly optimised C / Fortran libraries, so it offers very good performance.
# * **pylab**: For plotting and visualising the data.
# * **scipy**: The scientific toolset for Python. We will use it for its sparse linear algebra capabilities.

# %%
import pandas as pd
import numpy as np
import pylab as pl
import seaborn as sns  # Better looking defaults for plots
from datetime import datetime

# %% [markdown]
# # Loading the data

# %%
# Read the ratings
ratings = pd.read_csv('ml-1m/ratings.dat', sep='::', header=None)
ratings.columns = ['user', 'item', 'rating', 'ts']
# Parse the timestamps
ratings['ts'] = ratings['ts'].map(datetime.fromtimestamp)
# Read the movie ID - name mapping
movies = pd.read_csv('ml-1m/movies.dat', sep='::', header=None)
movies.columns = ['item', 'title', 'genre']

# %% [markdown]
# # Basic investigations
# Let's get some basic descriptive statistics about the distribution of the ratings.

# %%
ratings['rating'].describe()
# Out:
# count    1000209.000000
# mean           3.581564
# std            1.117102
# min            1.000000
# 25%            3.000000
# 50%            4.000000
# 75%            4.000000
# max            5.000000
# Name: rating, dtype: float64

# %% [markdown]
# Now let's calculate the frequency of each rating and plot it in a histogram

# %%
rating_hist = ratings['rating'].value_counts()
rating_hist
# Out:
# 4    348971
# 3    261197
# 5    226310
# 2    107557
# 1     56174
# dtype: int64

# %%
# %matplotlib inline
pl.bar(rating_hist.index.values - 0.5, rating_hist.values)
pl.title('Histogram of ratings')

# %% [markdown]
# ## Movie popularity

# %% [markdown]
# Now let's try a slightly more fine-grained analysis. Let's look at the ratings once aggregated per movie. Specifically, plot the histogram of the number of ratings per movie and the histogram of the average rating per movie. For the latter, include only movies with a substantial number of ratings (e.g. >10) for a more robust characterisation.

# %%
ratings_per_movie = ratings.groupby('item')['rating']
num_ratings_per_movie = ratings_per_movie.count()
print num_ratings_per_movie.describe()
num_ratings_per_movie.hist(bins=100)
pl.xlabel('Number of ratings')
pl.ylabel('Number of movies')
# Out:
# count    3706.000000
# mean      269.889099
# std       384.047838
# min         1.000000
# 25%        33.000000
# 50%       123.500000
# 75%       350.000000
# max      3428.000000
# Name: rating, dtype: float64

# %%
avg_rating_per_movie = ratings_per_movie.mean()
print avg_rating_per_movie.describe()
avg_rating_per_movie[num_ratings_per_movie > 10].hist(bins=100)
pl.xlabel('Average rating')
pl.ylabel('Number of movies')
# Out:
# count    3706.000000
# mean        3.238892
# std         0.672925
# min         1.000000
# 25%         2.822705
# 50%         3.331546
# 75%         3.740741
# max         5.000000
# Name: rating, dtype: float64

# %% [markdown]
# # Train / test split

# %% [markdown]
# In order to be able to characterise the performance of our recommender system we need to split the data into train and test subsets so that evaluation can be performed on samples that were not used during the learning process. We are also going to pre-filter the dataset to use only relatively frequent users. Create a new DataFrame called `subset` which only contains information about users with more than 25 ratings.

# %%
ratings_all = ratings

THRESH = 25
ratings_per_user = ratings.groupby('user')['rating'].count()
candidates = ratings_per_user[ratings_per_user > THRESH].index
subset = ratings[ratings['user'].isin(candidates)]

# %% [markdown]
# Now create two DataFrames `ratings_test` and `ratings_train`. They should form a random, non-overlapping partition of `subset`. Let `ratings_test` contain 100000 ratings.

# %%
TEST_SIZE = 100000
test_idx = np.random.choice(subset.index, TEST_SIZE, replace=False)
ratings_test = ratings.ix[test_idx]
train_idx = np.setdiff1d(subset.index.values, test_idx)
ratings_train = ratings.ix[train_idx]
ratings = ratings_train

# %% [markdown]
# # Modeling the ratings
#
# Let's start with a very simple model
#
# $$
# \hat{r}_{ij} = \mu + b^{(u)}(i) + b^{(i)}(j)
# $$
#
# where $b^{(u)}$ is a vector containing per-user biases, $b^{(i)}$ contains per-item biases and $\mu$ is a global bias. Obviously we can drop the $\mu$ term if we first make the ratings zero-mean so that we can define
#
# $$
# \tilde{r}_{ij} = r_{ij} - \mu = r_{ij} - \frac{1}{N}\sum_{(x,y) \in \mathcal{D}} r_{x,y}
# $$
#
# In the next cell, add a new column to the `ratings` DataFrame called `rating_n` which contains a zero-mean version of the original ratings.

# %%
ratings['rating_n'] = ratings['rating'] - ratings['rating'].mean()

# %% [markdown]
# Let's check that the column is actually zero-mean

# %%
# Let's check
assert(abs(ratings['rating_n'].mean()) < 1e-5)
ratings['rating_n'].describe()
# Out:
# count    8.892020e+05
# mean     7.429345e-14
# std      1.117013e+00
# min     -2.579675e+00
# 25%     -5.796748e-01
# 50%      4.203252e-01
# 75%      4.203252e-01
# max      1.420325e+00
# Name: rating_n, dtype: float64

# %% [markdown]
# Great! Let's see what's our baseline MSE using just this global bias term

# %%
global_mse = (ratings['rating_n'] ** 2).mean()
print "MSE with just a global bias term: %.3f" % global_mse
# Out:
# MSE with just a global bias term: 1.248

# %% [markdown]
# ## Learning user and item biases
# So now we can user $\tilde{r}_{ij}$ as our targets and simplify our model to
#
# $$
# \hat{r}_{ij} = b^{(u)}(i) + b^{(i)}(j)
# $$
#
# How can we learn the bias parameters $b^{(u)}$ and $b^{(i)}$? The usual solution implies simply closed-form minimization of the residuals of previous effects (see e.g. Sec 2.1 of [this survey](http://files.grouplens.org/papers/FnT%20CF%20Recsys%20Survey.pdf))
#
# $$
# b^{(u)} = \frac{1}{|I(i)| + \gamma}\sum_{j \in I(i)} (\tilde{r}_{ij}) \\
# b^{(i)} = \frac{1}{|U(j)| + \gamma}\sum_{i \in U(j)} (\tilde{r}_{ij} - b^{(u)}(i))
# $$
#
# where $\gamma$ is a regularisation term, $I(i)$ is the set of items that have been rated by user $i$ and $U(j)$ is the set of users that have rated item $j$.

# %%
r = 25 # Regularisation factor (a.k.a. magic number)
sum_cnt = ratings.groupby('user')['rating_n'].agg({"sum": np.sum, "count": len})
b_u = sum_cnt['sum'] / (sum_cnt['count'] + r)
b_u.name = 'b_u'
wip = ratings.merge(b_u.reset_index(), on='user')
wip.head()
# Out:
#    user  item  rating                  ts  rating_n       b_u
# 0     1  1193       5 2001-01-01 09:12:40  1.420325  0.399084
# 1     1   914       3 2001-01-01 09:32:48 -0.579675  0.399084
# 2     1  3408       4 2001-01-01 09:04:35  0.420325  0.399084
# 3     1  2355       5 2001-01-07 10:38:11  1.420325  0.399084
# 4     1  1197       3 2001-01-01 09:37:48 -0.579675  0.399084

# %%
# Regularised bias estmation
wip['residual'] = wip['rating_n'] - wip['b_u']
sum_cnt = wip.groupby('item')['residual'].agg({"sum": np.sum, "count": len})
b_i = sum_cnt['sum'] / (sum_cnt['count'] + r)
b_i.name = 'b_i'
wip = wip.merge(b_i.reset_index(), on='item')
wip.head()
# Out:
#    user  item  rating                  ts  rating_n       b_u  residual  \
# 0     1  1193       5 2001-01-01 09:12:40  1.420325  0.399084  1.021241
# 1     2  1193       5 2001-01-01 08:33:33  1.420325  0.116696  1.303629
# 2    15  1193       4 2000-12-31 05:01:19  0.420325 -0.237481  0.657806
# 3    17  1193       5 2000-12-30 17:41:11  1.420325  0.455832  0.964494
# 4    19  1193       5 2001-02-21 15:48:56  1.420325 -0.059300  1.479625
#
#        b_i
# 0  0.70455
# 1  0.70455
# 2  0.70455
# 3  0.70455
# 4  0.70455

# %%
wip['pred_baseline'] = wip['b_u'] + wip['b_i']
#pred_baseline.name = 'pred_baseline'

ratings_with_pred = ratings.merge(wip[['user','item','pred_baseline']], on=['user','item'])
ratings_with_pred.head(10)
# Out:
#    user  item  rating                  ts  rating_n  pred_baseline
# 0     1  1193       5 2001-01-01 09:12:40  1.420325       1.103634
# 1     1   914       3 2001-01-01 09:32:48 -0.579675       0.861519
# 2     1  3408       4 2001-01-01 09:04:35  0.420325       0.637264
# 3     1  2355       5 2001-01-07 10:38:11  1.420325       0.645622
# 4     1  1197       3 2001-01-01 09:37:48 -0.579675       1.041280
# 5     1  1287       5 2001-01-01 09:33:59  1.420325       0.840146
# 6     1  2804       5 2001-01-01 09:11:59  1.420325       0.986253
# 7     1   594       4 2001-01-01 09:37:48  0.420325       0.625921
# 8     1   919       4 2001-01-01 09:22:48  0.420325       0.963053
# 9     1  2398       4 2001-01-01 09:38:01  0.420325       0.748625

# %% [markdown]
# Let's make sure that our new model which incorporates per-user and per-item biases represents the original dataset more accurately.

# %%
# Error calculation
ratings_with_pred['res_baseline'] = ratings_with_pred['rating_n'] - ratings_with_pred['pred_baseline']
mse_baseline = (ratings_with_pred['res_baseline'] ** 2).mean()
print "MSE with user / item /gobal biases: %.3f" % mse_baseline
# Out:
# MSE with user / item /gobal biases: 0.843

# %% [markdown]
# Obviously the reconstruction error on the training set is not that informative about the real-world performance of a model. Let's check now the error on the test set that we prepared earlier. Calculate both the MSE and the reduction in variance.

# %%
user_bound = ratings['user'].max() + 1
item_bound = ratings['item'].max() + 1

b_u_v = b_u.reindex(np.arange(user_bound)).fillna(0).values
b_i_v = b_i.reindex(np.arange(item_bound)).fillna(0).values
B_u = b_u_v[:, np.newaxis].repeat(item_bound, 1)
B_i = b_i_v[np.newaxis, :].repeat(user_bound, 0)
P_basic = B_u + B_i

pred = np.zeros(len(ratings_test))

pred = P_basic[ratings_test['user'], ratings_test['item']]

signal = ratings_test['rating'].std()
print "MSE on the test set: %.3f"% ((ratings_test['rating'] - ratings_test['rating'].mean() - pred)**2).mean()
print "Variance reduction on test set: %.3f%%" % ((1 - ((ratings_test['rating'] - ratings_test['rating'].mean() - pred) ** 2).mean()/signal) * 100)
# Out:
# MSE on the test set: 0.859
# Variance reduction on test set: 23.015%

# %% [markdown]
# How does the result look like? Is it similar to the error on the training set? Is that a good sign?

# %% [markdown]
# ## Latent variables / matrix factorisation

# %% [markdown]
# We will now try to capture the variance unexplained by the user / item biases using a latent space representation. The model that we are after is given by:
#
# $$
# \hat{r}_{ij} = b^{(u)}(i) + b^{(i)}(j) + \sum_{d=1}^D w_{id}v_{jd} = b^{(u)}(i) + b^{(i)}(j) + w_i^Tv_j
# $$
#
# where $w_i$ and $v_j$ are the *latent representations* of user $i$ and item $j$ respectively. We can learn those latent representations by factorising the residual matrix (i.e. the matrix of the difference between the actual rankings and our bias-based estimates). The natural choice for the job is the Singular Value Decomposition (SVD). Moreover, since our rating matrix is sparse (there are a lot of (user, item) pairs for which we have no rating) we should use sparse matrix representations. Luckily for us, the `scipy` package provides sparse linear algebra functionality out of the box in the `svds` function, wrapping the well-known `ARPACK` library.

# %%
from scipy.sparse.csc import csc_matrix
from scipy.sparse.linalg import svds

# Construct a sparse matrix of ratings
idx = ratings_with_pred[['user', 'item']].values
v = ratings_with_pred['res_baseline'].values
M = csc_matrix((v, (idx[:,0], idx[:,1])), shape=(user_bound, item_bound))

# Sparse SVD
D = 10  # Latent space dimension
[W,U,V] = svds(M, D)
svd_pred = W.dot(np.diag(U)).dot(V)  # Low-rank reconstruction

# %%
# Combine with the baseline predictions
P_svd = svd_pred + P_basic

pred_svd_train = P_svd[ratings_with_pred['user'], ratings_with_pred['item']]

# %%
ratings_with_pred['pred_svd'] = pred_svd_train
ratings_with_pred['res_svd'] = ratings_with_pred['rating_n'] - ratings_with_pred['pred_svd']
mse_svd_train = (ratings_with_pred['res_svd'] ** 2).mean()
print "Mean square error with SVD decomposition (%i dimensions) on training set: %f " % (D, mse_svd_train)
# Out:
# Mean square error with SVD decomposition (10 dimensions) on training set: 0.751639

# %% [markdown]
# Let's now evaluate the performance on the test set

# %%
pred_svd_test = P_svd[ratings_test['user'], ratings_test['item']]
err_test = ratings_test['rating'] - pred_svd_test - ratings_test['rating'].mean()
mse_svd_test = (err_test ** 2).mean()
print "MSE with SVD decomposition on test set: %.3f" % mse_svd_test
print "Variance reduction: %.3f%%"  % ((1 - ((ratings_test['rating'] - ratings_test['rating'].mean() - pred_svd_test) ** 2).mean()/signal) * 100)
# Out:
# MSE with SVD decomposition on test set: 0.796
# Variance reduction: 28.620%

# %% [markdown]
# Let's now explore the predictions. First let's look at our predictions for a user's favorite films and compare it with the actual ratings that user provided

# %%
USER = 6040  # Pick your favorite
user_ratings = ratings_with_pred[ratings_with_pred['user'] == USER]
user_ratings = user_ratings[['user','item','rating','pred_baseline','pred_svd']]
user_ratings = pd.merge(user_ratings, movies, on='item')
user_ratings.sort('pred_svd', ascending=False)
# Out:
#      user  item  rating  pred_baseline  pred_svd  \
# 70   6040   608       4       0.583336  0.979338
# 245  6040   858       4       0.819481  0.956616
# 294  6040  2019       5       0.834833  0.892134
# 15   6040   912       5       0.717102  0.874971
# 19   6040   923       5       0.686329  0.864261
# 157  6040  1221       4       0.673261  0.811332
# 176  6040  1252       5       0.633072  0.809420
# 141  6040    50       4       0.854385  0.788776
# 150  6040  1212       5       0.705506  0.784518
# 82   6040  1193       4       0.702929  0.782478
# 295  6040   541       4       0.598606  0.769748
# 13   6040   908       4       0.695454  0.766243
# 289  6040   527       5       0.821011  0.758885
# 181  6040  2997       4       0.467091  0.726924
# 178  6040   720       4       0.735792  0.705862
# 174  6040  1250       4       0.681940  0.683360
# 258  6040   111       5       0.493765  0.674615
# 151  6040  1213       4       0.609192  0.668736
# 147  6040  1208       5       0.560989  0.667161
# 206  6040  1617       4       0.531549  0.667010
# 92   6040  3134       5       0.560316  0.664443
# 31   6040  3089       5       0.591979  0.664258
# 282  6040  2762       4       0.757150  0.662193
# 165  6040  1237       5       0.544067  0.652184
# 169  6040  1247       4       0.536407  0.642170
# 51   6040   246       5       0.518934  0.639481
# 154  6040  1219       5       0.551630  0.639465
# 117  6040  1945       5       0.552041  0.623575
# 60   6040   296       4       0.617704  0.620785
# 5    6040   593       5       0.681492  0.612609
# ..    ...   ...     ...            ...       ...
# 170  6040  2987       1       0.083527 -0.456116
# 86   6040  2146       1      -0.378139 -0.466634
# 97   6040  2513       1      -0.426562 -0.476454
# 253  6040  2369       3      -0.589667 -0.523312
# 187  6040  1270       3       0.355986 -0.546227
# 4    6040   592       2       0.015819 -0.548192
# 270  6040  2716       2       0.284519 -0.557536
# 208  6040  2286       1      -0.563010 -0.573696
# 202  6040  2241       1      -0.554492 -0.592640
# 148  6040  1210       2       0.387093 -0.593301
# 7    6040  3017       1      -0.624881 -0.645315
# 145  6040  1991       1      -0.589264 -0.657169
# 290  6040  2003       1      -0.240401 -0.661385
# 222  6040  2641       2      -0.336205 -0.663445
# 25   6040  2410       1      -0.528082 -0.669470
# 20   6040  2402       1      -0.621993 -0.707835
# 293  6040  2011       4      -0.188607 -0.734080
# 257  6040  2378       1      -0.460595 -0.744008
# 288  6040  2794       1      -0.529131 -0.749351
# 271  6040  2717       1      -0.540234 -0.763285
# 276  6040  3388       1      -0.692207 -0.774405
# 304  6040  1091       1      -0.612270 -0.783667
# 242  6040  1373       3      -0.729030 -0.842560
# 42   6040  2471       1      -0.766118 -0.861472
# 29   6040  2421       1      -0.763579 -0.874088
# 22   6040  2408       1      -0.819206 -0.881451
# 26   6040  2411       1      -0.766428 -0.907591
# 87   6040  2147       2      -0.873771 -0.909498
# 139  6040  1975       1      -0.851464 -0.929485
# 38   6040  2456       1      -1.004868 -1.017924
#
#                                                  title  \
# 70                                        Fargo (1996)
# 245                              Godfather, The (1972)
# 294  Seven Samurai (The Magnificent Seven) (Shichin...
# 15                                   Casablanca (1942)
# 19                                 Citizen Kane (1941)
# 157                     Godfather: Part II, The (1974)
# 176                                   Chinatown (1974)
# 141                         Usual Suspects, The (1995)
# 150                              Third Man, The (1949)
# 82              One Flew Over the Cuckoo's Nest (1975)
# 295                                Blade Runner (1982)
# 13                           North by Northwest (1959)
# 289                            Schindler's List (1993)
# 181                        Being John Malkovich (1999)
# 178  Wallace & Gromit: The Best of Aardman Animatio...
# 174               Bridge on the River Kwai, The (1957)
# 258                                 Taxi Driver (1976)
# 151                                  GoodFellas (1990)
# 147                              Apocalypse Now (1979)
# 206                           L.A. Confidential (1997)
# 92         Grand Illusion (Grande illusion, La) (1937)
# 31     Bicycle Thief, The (Ladri di biciclette) (1948)
# 282                            Sixth Sense, The (1999)
# 165    Seventh Seal, The (Sjunde inseglet, Det) (1957)
# 169                               Graduate, The (1967)
# 51                                  Hoop Dreams (1994)
# 154                                      Psycho (1960)
# 117                           On the Waterfront (1954)
# 60                                 Pulp Fiction (1994)
# 5                     Silence of the Lambs, The (1991)
# ..                                                 ...
# 170                    Who Framed Roger Rabbit? (1988)
# 86                              St. Elmo's Fire (1985)
# 97                                 Pet Sematary (1989)
# 253                   Desperately Seeking Susan (1985)
# 187                          Back to the Future (1985)
# 4                                        Batman (1989)
# 270                                Ghostbusters (1984)
# 208         Fiendish Plot of Dr. Fu Manchu, The (1980)
# 202                                       Class (1983)
# 148  Star Wars: Episode VI - Return of the Jedi (1983)
# 7                                   Creepshow 2 (1987)
# 145                                Child's Play (1988)
# 290                                    Gremlins (1984)
# 222                                 Superman II (1980)
# 25                                    Rocky III (1982)
# 20                   Rambo: First Blood Part II (1985)
# 293                  Back to the Future Part II (1989)
# 257                              Police Academy (1984)
# 288                           European Vacation (1985)
# 271                             Ghostbusters II (1989)
# 276                    Harry and the Hendersons (1987)
# 304                         Weekend at Bernie's (1989)
# 242             Star Trek V: The Final Frontier (1989)
# 42                          Crocodile Dundee II (1988)
# 29                     Karate Kid, Part II, The (1986)
# 22                           Cocoon: The Return (1988)
# 26                                     Rocky IV (1985)
# 87                   Clan of the Cave Bear, The (1986)
# 139                      Friday the 13th Part 2 (1981)
# 38                                  Fly II, The (1989)
#
#                                    genre
# 70                  Crime|Drama|Thriller
# 245                   Action|Crime|Drama
# 294                         Action|Drama
# 15                     Drama|Romance|War
# 19                                 Drama
# 157                   Action|Crime|Drama
# 176           Film-Noir|Mystery|Thriller
# 141                       Crime|Thriller
# 150                     Mystery|Thriller
# 82                                 Drama
# 295                     Film-Noir|Sci-Fi
# 13                        Drama|Thriller
# 289                            Drama|War
# 181                               Comedy
# 178                            Animation
# 174                            Drama|War
# 258                       Drama|Thriller
# 151                          Crime|Drama
# 147                            Drama|War
# 206     Crime|Film-Noir|Mystery|Thriller
# 92                             Drama|War
# 31                                 Drama
# 282                             Thriller
# 165                                Drama
# 169                        Drama|Romance
# 51                           Documentary
# 154                      Horror|Thriller
# 117                          Crime|Drama
# 60                           Crime|Drama
# 5                         Drama|Thriller
# ..                                   ...
# 170        Adventure|Animation|Film-Noir
# 86                         Drama|Romance
# 97                                Horror
# 253                       Comedy|Romance
# 187                        Comedy|Sci-Fi
# 4           Action|Adventure|Crime|Drama
# 270                        Comedy|Horror
# 208                               Comedy
# 202                               Comedy
# 148  Action|Adventure|Romance|Sci-Fi|War
# 7                                 Horror
# 145                               Horror
# 290                        Comedy|Horror
# 222              Action|Adventure|Sci-Fi
# 25                          Action|Drama
# 20                            Action|War
# 293                        Comedy|Sci-Fi
# 257                               Comedy
# 288                               Comedy
# 271                        Comedy|Horror
# 276                               Comedy
# 304                               Comedy
# 242              Action|Adventure|Sci-Fi
# 42                      Adventure|Comedy
# 29                Action|Adventure|Drama
# 22                         Comedy|Sci-Fi
# 26                          Action|Drama
# 87                                 Drama
# 139                               Horror
# 38                         Horror|Sci-Fi
#
# [308 rows x 7 columns]

# %% [markdown]
# And now let's see what the model suggests as the best and worst recommendations for that user

# %%
sorted_pred = np.argsort(P_svd[USER, :])
top_films = sorted_pred[-20:]
worst_films = sorted_pred[:20]
print "Top picks"
movies[movies['item'].isin(top_films)]
# Out:
# Top picks
#       item                                              title  \
# 49      50                         Usual Suspects, The (1995)
# 537    541                                Blade Runner (1982)
# 604    608                                       Fargo (1996)
# 735    745                              Close Shave, A (1995)
# 740    750  Dr. Strangelove or: How I Learned to Stop Worr...
# 847    858                              Godfather, The (1972)
# 892    904                                 Rear Window (1954)
# 896    908                          North by Northwest (1959)
# 900    912                                  Casablanca (1942)
# 901    913                         Maltese Falcon, The (1941)
# 910    922      Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 911    923                                Citizen Kane (1941)
# 1132  1148                         Wrong Trousers, The (1993)
# 1176  1193             One Flew Over the Cuckoo's Nest (1975)
# 1186  1204                          Lawrence of Arabia (1962)
# 1189  1207                       To Kill a Mockingbird (1962)
# 1194  1212                              Third Man, The (1949)
# 1203  1221                     Godfather: Part II, The (1974)
# 1232  1252                                   Chinatown (1974)
# 1950  2019  Seven Samurai (The Magnificent Seven) (Shichin...
#
#                            genre
# 49                Crime|Thriller
# 537             Film-Noir|Sci-Fi
# 604         Crime|Drama|Thriller
# 735    Animation|Comedy|Thriller
# 740                   Sci-Fi|War
# 847           Action|Crime|Drama
# 892             Mystery|Thriller
# 896               Drama|Thriller
# 900            Drama|Romance|War
# 901            Film-Noir|Mystery
# 910                    Film-Noir
# 911                        Drama
# 1132            Animation|Comedy
# 1176                       Drama
# 1186               Adventure|War
# 1189                       Drama
# 1194            Mystery|Thriller
# 1203          Action|Crime|Drama
# 1232  Film-Noir|Mystery|Thriller
# 1950                Action|Drama

# %%
print "Bottom picks"
movies[movies['item'].isin(worst_films)]
# Out:
# Bottom picks
#       item                                             title  \
# 179    181    Mighty Morphin Power Rangers: The Movie (1995)
# 542    546                          Super Mario Bros. (1993)
# 800    810                                     Kazaam (1996)
# 1360  1381                                   Grease 2 (1982)
# 1368  1389                                   Jaws 3-D (1983)
# 1517  1556                    Speed 2: Cruise Control (1997)
# 1929  1998                   Exorcist II: The Heretic (1977)
# 2084  2153                              Avengers, The (1998)
# 2312  2381       Police Academy 4: Citizens on Patrol (1987)
# 2313  2382  Police Academy 5: Assignment: Miami Beach (1988)
# 2314  2383         Police Academy 6: City Under Siege (1989)
# 2381  2450                            Howard the Duck (1986)
# 2486  2555                              Baby Geniuses (1999)
# 2574  2643           Superman IV: The Quest for Peace (1987)
# 2747  2816                              Iron Eagle II (1988)
# 2748  2817                       Aces: Iron Eagle III (1992)
# 3199  3268                 Stop! Or My Mom Will Shoot (1992)
# 3495  3564        Flintstones in Viva Rock Vegas, The (2000)
# 3524  3593                          Battlefield Earth (2000)
# 3730  3799                     Pok�mon the Movie 2000 (2000)
#
#                                    genre
# 179                    Action|Children's
# 542   Action|Adventure|Children's|Sci-Fi
# 800            Children's|Comedy|Fantasy
# 1360              Comedy|Musical|Romance
# 1368                       Action|Horror
# 1517             Action|Romance|Thriller
# 1929                              Horror
# 2084                    Action|Adventure
# 2312                              Comedy
# 2313                              Comedy
# 2314                              Comedy
# 2381         Adventure|Children's|Sci-Fi
# 2486                              Comedy
# 2574             Action|Adventure|Sci-Fi
# 2747                          Action|War
# 2748                          Action|War
# 3199                       Action|Comedy
# 3495                   Children's|Comedy
# 3524                       Action|Sci-Fi
# 3730                Animation|Children's
